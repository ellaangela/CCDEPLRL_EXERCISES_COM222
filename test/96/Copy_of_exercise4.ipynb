# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
#!wget https://bitbucket.org/ishaanjav/code-and-deploy-custom-tensorflow-lite-model/raw/a4febbfee178324b2083e322cdead7465d6fdf95/fruits.zip

# %%
#!unzip fruits.zip

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 600 files belonging to 4 classes.
# Found 86 files belonging to 4 classes.
# Found 164 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
# prompt: Display sample images from the dataset (under the main folder named fruits there are 3 folders inside for test train and validation, the fruits that will be used are "apple", "banana", "orange", "durian")

import matplotlib.pyplot as plt

class_names = train_ds.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    tf.keras.layers.Conv2D(24, (3, 3), activation='relu', padding='same'),  # Increased filters
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),  # Increased filters
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(129, (3, 3), activation='relu', padding='same'), # Increased filters
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),  # Increased units
    tf.keras.layers.Dropout(0.3),                  # Added dropout for regularization
    tf.keras.layers.Dense(len(class_names), activation='softmax') # Added softmax activation
])

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 25
)
# Out:
# Epoch 1/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.3726 - loss: 1.3741 - val_accuracy: 0.4651 - val_loss: 1.1550
# Epoch 2/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6714 - loss: 0.8751 - val_accuracy: 0.8256 - val_loss: 0.6341
# Epoch 3/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8648 - loss: 0.6253 - val_accuracy: 0.9186 - val_loss: 0.5230
# Epoch 4/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8612 - loss: 0.5840 - val_accuracy: 0.9302 - val_loss: 0.4813
# Epoch 5/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9370 - loss: 0.4651 - val_accuracy: 0.9884 - val_loss: 0.4141
# Epoch 6/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9428 - loss: 0.4714 - val_accuracy: 0.9651 - val_loss: 0.4335
# Epoch 7/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9595 - loss: 0.4251 - val_accuracy: 0.9186 - val_loss: 0.4541
# Epoch 8/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9586 - loss: 0.4209 - val_accuracy: 0.8605 - val_loss: 0.5864
# Epoch 9/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9514 - loss: 0.4501 - val_accuracy: 0.9651 - val_loss: 0.4131
# Epoch 10/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9781 - loss: 0.3956 - val_accuracy: 0.9186 - val_loss: 0.4657
# Epoch 11/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9528 - loss: 0.4261 - val_accuracy: 0.9651 - val_loss: 0.4335
# Epoch 12/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9614 - loss: 0.4204 - val_accuracy: 0.9767 - val_loss: 0.3791
# Epoch 13/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9705 - loss: 0.3994 - val_accuracy: 0.9535 - val_loss: 0.4143
# Epoch 14/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9633 - loss: 0.4129 - val_accuracy: 0.9535 - val_loss: 0.4368
# Epoch 15/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9669 - loss: 0.4124 - val_accuracy: 0.9651 - val_loss: 0.4142
# Epoch 16/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9746 - loss: 0.3897 - val_accuracy: 0.9767 - val_loss: 0.3938
# Epoch 17/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9731 - loss: 0.3964 - val_accuracy: 0.9302 - val_loss: 0.4685
# Epoch 18/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9873 - loss: 0.3699 - val_accuracy: 0.8837 - val_loss: 0.5161
# Epoch 19/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.9748 - loss: 0.3985 - val_accuracy: 0.9535 - val_loss: 0.4166
# Epoch 20/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9733 - loss: 0.3939 - val_accuracy: 0.9651 - val_loss: 0.4069
# Epoch 21/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9751 - loss: 0.3792 - val_accuracy: 0.9535 - val_loss: 0.4057
# Epoch 22/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9883 - loss: 0.3701 - val_accuracy: 0.9767 - val_loss: 0.3926
# Epoch 23/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9542 - loss: 0.4134 - val_accuracy: 0.9651 - val_loss: 0.3966
# Epoch 24/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9892 - loss: 0.3717 - val_accuracy: 0.9186 - val_loss: 0.4769
# Epoch 25/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9843 - loss: 0.3735 - val_accuracy: 0.9651 - val_loss: 0.3942

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9670 - loss: 0.4085
# [0.4276207387447357, 0.957317054271698]

# %%
import numpy

plt.figure(figsize=(13,13))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %% [markdown]
# Save the model

# %%
model.save('model.keras')
